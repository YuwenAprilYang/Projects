# %% [markdown]
# ## Spotify Wrapped: Analyzing My Top Tracks Over Time 🎵

# %% [markdown]
# ### Project Overview:
# As a loyal Spotify user, I want to check my Spotify Wrapped anytime I want. But currently, I can only check it when it's the end of the year.
# Therefore, the goal of the project is to have access to my Spotify top tracks any time I want, and gain insights into how my music preferences evolve over time

# %%
## Import Packages
import requests
import spotipy
from spotipy.oauth2 import SpotifyOAuth
import pandas as pd
import time
import datetime

# %%
from spotipy.oauth2 import SpotifyOAuth

# %%
## Set up my Client ID and Client Secret from Spotify

Client_ID = "MyClientID"
Client_Secret = "MyClientSecret"
URL = "http://127.0.0.1:9090/"
Scope= "user-top-read"

# %%
## Set path to my Spotify Account
sp = spotipy.Spotify(auth_manager=SpotifyOAuth(client_id=Client_ID, 
                                               client_secret= Client_Secret,
                                              redirect_uri=URL,
                                              scope= Scope))

# %%
## Top Song Tracks on Spotify in Different Periods of Time
## Short Term: Time Range of 4 Weeks
## Medium Term: Time Range of 6 Months
## Long Term: Time Range of Several Years

short_term_songs = sp.current_user_top_tracks(limit= 20, offset=0,time_range="short_term")
medium_term_songs = sp.current_user_top_tracks(limit= 20, offset=0,time_range="medium_term")
long_term_songs = sp.current_user_top_tracks(limit= 20, offset=0,time_range="long_term")

# %%
## Extract Song Track ID

def get_track_id(time_frame):
    track_ids=[]
    for song in time_frame['items']:
        track_ids.append(song['id'])
    return track_ids

# %%
short_track_ids = get_track_id(short_term_songs)
medium_track_ids = get_track_id(medium_term_songs)
long_track_ids = get_track_id(long_term_songs)

# %%
## Get each track feature
## Including Song name, artist name, album name

def get_features(id):
    package = sp.track(id)
    name = package['name']
    album = package['album']['name']
    artist = package['album']['artists'][0]['name']
    track_info = [name, album, artist]
    return track_info

# %%
## Loop over track ids

## For short terms
short_tracks = []
for i in range(len(short_track_ids)):
    time.sleep(.5)
    track = get_features(short_track_ids[i])
    short_tracks.append(track)

# %%
## Save in a dataset
df_short = pd.DataFrame(short_tracks, columns = ['Name','Album','Artist'])
df_short
# Out:
#                                       Name  \
# 0                                     才二十三
# 1       Love Hangover (feat. Dominic Fike)
# 2                         Good Luck, Babe!
# 3                                 Whiplash
# 4       Girl, so confusing featuring lorde
# 5                                   Mantra
# 6                      Sympathy is a knife
# 7                                      365
# 8                        Run For Your Life
# 9                                    Drive
# 10                    Open Arms (just SZA)
# 11                                   Spicy
# 12           Guess featuring billie eilish
# 13                             Abracadabra
# 14                         Just Like Honey
# 15                            Funny Papers
# 16                          Pink Pony Club
# 17  I Don't Believe The Chart Prod. PEEJAY
# 18                Joni (feat. Don Toliver)
# 19      Wheels Fall Off (feat. Kanye West)
#
#                                                 Album  \
# 0                                     夢想家 The Dreamer
# 1                  Love Hangover (feat. Dominic Fike)
# 2                                    Good Luck, Babe!
# 3                       Whiplash - The 5th Mini Album
# 4   Brat and it’s completely different but also st...
# 5                                              Mantra
# 6                                                BRAT
# 7                                                BRAT
# 8                                   Run For Your Life
# 9                                    SOS Deluxe: LANA
# 10                                   SOS Deluxe: LANA
# 11                       iScreaM Vol.26 : Spicy Remix
# 12  Brat and it’s completely different but also st...
# 13                                        Abracadabra
# 14                     Psychocandy (Expanded Version)
# 15                                       Balloonerism
# 16            The Rise and Fall of a Midwest Princess
# 17                                               DEMO
# 18                                   SOS Deluxe: LANA
# 19                 Wheels Fall Off (feat. Kanye West)
#
#                       Artist
# 0                Khalil Fong
# 1                     JENNIE
# 2              Chappell Roan
# 3                      aespa
# 4                 Charli xcx
# 5                     JENNIE
# 6                 Charli xcx
# 7                 Charli xcx
# 8              Tiffany Young
# 9                        SZA
# 10                       SZA
# 11                     aespa
# 12                Charli xcx
# 13                 Lady Gaga
# 14  The Jesus and Mary Chain
# 15                Mac Miller
# 16             Chappell Roan
# 17                  Wonstein
# 18                       SZA
# 19             Ty Dolla $ign

# %%
## Loop over track ids

## For medium terms
medium_tracks = []
for i in range(len(medium_track_ids)):
    time.sleep(.5)
    track = get_features(medium_track_ids[i])
    medium_tracks.append(track)

# %%
## Save in a dataset
df_medium = pd.DataFrame(medium_tracks, columns = ['Name','Album','Artist'])
df_medium
# Out:
#                                   Name  \
# 0                             Whiplash
# 1                                Taste
# 2                            PROMOTION
# 3   Girl, so confusing featuring lorde
# 4                 Needle (feat. Drake)
# 5                    Cherish (My Love)
# 6           either on or off the drugs
# 7                             再見以前先說再見
# 8                             Love 119
# 9                               MANIAC
# 10                                BODY
# 11                 Sympathy is a knife
# 12               SOMETHING AIN'T RIGHT
# 13                         Superpowers
# 14                          FIELD TRIP
# 15                Like It (with 6LACK)
# 16                            Espresso
# 17       Guess featuring billie eilish
# 18               Brought The Heat Back
# 19                 Scorsese Baby Daddy
#
#                                                 Album             Artist
# 0                       Whiplash - The 5th Mini Album              aespa
# 1                                      Short n' Sweet  Sabrina Carpenter
# 2                                          VULTURES 2                 ¥$
# 3   Brat and it’s completely different but also st...         Charli xcx
# 4                                       Pink Friday 2        Nicki Minaj
# 5                         Cherish (My Love) (Remixes)              ILLIT
# 6                          I LAY DOWN MY LIFE FOR YOU          JPEGMAFIA
# 7                                              陶喆同名專輯          David Tao
# 8                        RIIZING - The 1st Mini Album              RIIZE
# 9                         The 4th Mini Album 'VERSUS'              VIVIZ
# 10                                              TOXIC              MEOVV
# 11                                               BRAT         Charli xcx
# 12                                                AWE                 XG
# 13                                       NEVER ENOUGH      Daniel Caesar
# 14                                         VULTURES 2                 ¥$
# 15                                            Over It      Summer Walker
# 16                                     Short n' Sweet  Sabrina Carpenter
# 17  Brat and it’s completely different but also st...         Charli xcx
# 18                                   ROMANCE : UNTOLD            ENHYPEN
# 19                                   SOS Deluxe: LANA                SZA

# %%
## Loop over track ids

## For long terms
long_tracks = []
for i in range(len(long_track_ids)):
    time.sleep(.5)
    track = get_features(long_track_ids[i])
    long_tracks.append(track)

# %%
## Save in a dataset
df_long = pd.DataFrame(long_tracks, columns = ['Name','Album','Artist'])
df_long
# Out:
#                                                  Name  \
# 0                                   Say Yes To Heaven
# 1          Let The Light In (feat. Father John Misty)
# 2                                           Love song
# 3                                              Snooze
# 4                                                易碎之物
# 5                                   Tulsa Jesus Freak
# 6   Did you know that there's a tunnel under Ocean...
# 7                                    eternal sunshine
# 8                    Chemtrails Over The Country Club
# 9                          Margaret (feat. Bleachers)
# 10                           Happiness is a butterfly
# 11                                 Terrence Loves You
# 12                                    Taco Truck x VB
# 13                                         West Coast
# 14                                             Cherry
# 15                                        White Dress
# 16  Too Many Nights (feat. Don Toliver & with Future)
# 17                                      Cinnamon Girl
# 18                                              Rover
# 19                        Destroy Myself Just For You
#
#                                                 Album         Artist
# 0                                   Say Yes To Heaven   Lana Del Rey
# 1   Did you know that there's a tunnel under Ocean...   Lana Del Rey
# 2                            Norman Fucking Rockwell!   Lana Del Rey
# 3                                                 SOS            SZA
# 4                                            银河上升的三秒钟            阿弗娄
# 5                    Chemtrails Over The Country Club   Lana Del Rey
# 6   Did you know that there's a tunnel under Ocean...   Lana Del Rey
# 7                                    eternal sunshine  Ariana Grande
# 8                    Chemtrails Over The Country Club   Lana Del Rey
# 9   Did you know that there's a tunnel under Ocean...   Lana Del Rey
# 10                           Norman Fucking Rockwell!   Lana Del Rey
# 11                                          Honeymoon   Lana Del Rey
# 12  Did you know that there's a tunnel under Ocean...   Lana Del Rey
# 13                             Ultraviolence (Deluxe)   Lana Del Rey
# 14                                      Lust For Life   Lana Del Rey
# 15                   Chemtrails Over The Country Club   Lana Del Rey
# 16                                  HEROES & VILLAINS   Metro Boomin
# 17                           Norman Fucking Rockwell!   Lana Del Rey
# 18                         Rover - The 3rd Mini Album            KAI
# 19                                              JAMIE   Montell Fish
